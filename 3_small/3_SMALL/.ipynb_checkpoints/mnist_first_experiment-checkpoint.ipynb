# %%
# Using Keras to create a 10 neurons and single layer NN
# Against the MNIST databesa

from keras.datasets import mnist
from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
import keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (7,7) # Make the figures a bit bigger
nb_classes = 10

np.random.seed(42)
# %matplotlib notebook
# Out:
# Using TensorFlow backend.

# %%
# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print("X_train original shape", X_train.shape)
print("y_train original shape", y_train.shape)

# Swish activation function
# x*sigmoid(x)
def swish(x):
    return x*K.sigmoid(x)

# Custom activation function 1
# mix between relu and positive part of swish mirrored across x=1
def leaky(x):
    return K.maximum(0.3*x, x)

# Custom activation function 2
# positive part of swish mirrored across x=1
def e_swish_2(x):
    return K.maximum(x*K.sigmoid(x), x*(2-K.sigmoid(x)))

show(X_train, y_train)

# Reshape arrays
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)

Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)
# Out:
# X_train original shape (60000, 28, 28)
# y_train original shape (60000,)
# <img src="data:image/png;base64,..." width="640">
# Training matrix shape (60000, 784)
# Testing matrix shape (10000, 784)

# %%
activations = [e_swish_1, e_swish_2, swish, "relu", "elu", leaky] #  "sigmoid", "tanh"
names = activations[:]
for i,a in enumerate(names):
    if not isinstance(a, str):
        names[i] = a.__name__
print(names)
# Out:
# ['e_swish_1', 'e_swish_2', 'swish', 'relu', 'sigmoid', 'tanh']

# %%
def accuracy(y_pred, y_test):
    y_hat = np.argmax(y_pred, axis=1)
    y = np.argmax(y_test, axis=1)

    good = np.sum(np.equal(y, y_hat))
    return float(good/len(y_test))

# %%
def create(act):
    models = []

    sgd = SGD(lr=0.1)
    # create model
    
        model1 = Sequential()
        model1.add(Dense(200, input_dim=784, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(100, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(60, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(30, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(10, activation='softmax'))

    # Compile model
    model1.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    
    return model1

# %%
# Configure logs
import logging

# Record settings
LOG_FORMAT = "%(levelname)s %(asctime)s - %(message)s"
logging.basicConfig(filename="swish_first_exp_log.txt",format = LOG_FORMAT, level = logging.DEBUG, filemode = "a")
logs = logging.getLogger()

# %%
import gc
for i,act in enumerate(activations):
    logs.info("\n \n Starting traiing for "+names[i])
    ensembler = 0
    logger = [names[i]]
    for i in range(3):
        gc.collect()
        model = create(act)
        his = model.fit(X_train, Y_train, epochs=15, batch_size=64,  verbose=1, validation_data=(X_test, Y_test))
        # Record accuracy of each model and save it
        logger.append(model.evaluate(X_test, Y_test)[1])
        # Calculate probabilities of test data and sum them toghether
        ensembler += model.predict_proba(X_test)
        # Clear session (GPU MEMORY)
        K.get_session().close()
        K.set_session(K.tf.Session())
        del model, his
        
    # Calculate the median accuracy
    ensembled = accuracy(ensembler, Y_test)
    print(ensembled)
    logs.info(str(logger))
    logs.info(str(ensembled))
    del ensembler, ensembled

# %%
def test_against(models, epochs, acc):
   
        
    for j in range(epochs):
        for i,model in enumerate(models):
            print("Training model {0}".format(i))
            model.fit(X_train, Y_train, epochs=1, batch_size=64,  verbose=1, validation_data=(X_test, Y_test))
            scores = model.evaluate(X_test, Y_test)
            acc[i].append(scores[1]*100)
        print("///////////////////////////////////////////////")
        print("/////////////////////{0}//////////////////////////".format(j))
        print("///////////////////////////////////////////////")

    return models, acc

# Plot the evolution of the accuracies
def plot_results(accs):
	plt.figure()
	for acc in accs:
		plt.plot(acc)
	plt.grid()
	plt.legend(names, loc='upper left')
	plt.show()

# %%
kernels, acc = create_models()

# %%
kernels, acc = test_against(kernels, 20, acc)
# kernels_, acc = test_against(kernels_, 20, acc)
# Out:
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 7s - loss: 0.5469 - acc: 0.8348 - val_loss: 0.1882 - val_acc: 0.9460
#  9408/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.4493 - acc: 0.8665 - val_loss: 0.1623 - val_acc: 0.9489
#  9920/10000 [============================>.] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.6578 - acc: 0.7983 - val_loss: 0.2293 - val_acc: 0.9338
#  9344/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.6363 - acc: 0.7971 - val_loss: 0.1830 - val_acc: 0.9465
#  9664/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 2.3216 - acc: 0.1014 - val_loss: 2.2998 - val_acc: 0.1135
#  9760/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.4994 - acc: 0.8516 - val_loss: 0.2962 - val_acc: 0.9109
# 10000/10000 [==============================] - 0s
# ///////////////////////////////////////////////
# /////////////////////0//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2561 - acc: 0.9314 - val_loss: 0.1431 - val_acc: 0.9605
#  9312/10000 [==========================>...] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2157 - acc: 0.9402 - val_loss: 0.1268 - val_acc: 0.9627
#  9536/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2740 - acc: 0.9210 - val_loss: 0.1586 - val_acc: 0.9517
# 10000/10000 [==============================] - 0s
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2651 - acc: 0.9277 - val_loss: 0.2092 - val_acc: 0.9382
#  9856/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 2.3046 - acc: 0.1077 - val_loss: 2.3005 - val_acc: 0.1135
#  9536/10000 [===========================>..] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.3130 - acc: 0.9095 - val_loss: 0.1969 - val_acc: 0.9423
#  9184/10000 [==========================>...] - ETA: 0s///////////////////////////////////////////////
# /////////////////////1//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2001 - acc: 0.9472 - val_loss: 0.1185 - val_acc: 0.9660
#  9568/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1636 - acc: 0.9549 - val_loss: 0.1063 - val_acc: 0.9684
#  9856/10000 [============================>.] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2043 - acc: 0.9413 - val_loss: 0.1287 - val_acc: 0.9596
#  9824/10000 [============================>.] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2051 - acc: 0.9455 - val_loss: 0.1165 - val_acc: 0.9673
#  9888/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 2.3020 - acc: 0.1122 - val_loss: 2.2975 - val_acc: 0.1135
#  9248/10000 [==========================>...] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2539 - acc: 0.9269 - val_loss: 0.1730 - val_acc: 0.9493
#  9920/10000 [============================>.] - ETA: 0s///////////////////////////////////////////////
# /////////////////////2//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1683 - acc: 0.9566 - val_loss: 0.1077 - val_acc: 0.9720
#  9984/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1404 - acc: 0.9617 - val_loss: 0.1027 - val_acc: 0.9693
#  9504/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1718 - acc: 0.9504 - val_loss: 0.1216 - val_acc: 0.9629
#  9472/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1662 - acc: 0.9563 - val_loss: 0.1082 - val_acc: 0.9698
#  9536/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 2.2992 - acc: 0.1164 - val_loss: 2.2938 - val_acc: 0.1135
#  9344/10000 [===========================>..] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2246 - acc: 0.9362 - val_loss: 0.1605 - val_acc: 0.9523
#  9856/10000 [============================>.] - ETA: 0s///////////////////////////////////////////////
# /////////////////////3//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1530 - acc: 0.9598 - val_loss: 0.1026 - val_acc: 0.9704
#  9472/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1246 - acc: 0.9649 - val_loss: 0.0866 - val_acc: 0.9743
#  9440/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1470 - acc: 0.9582 - val_loss: 0.1023 - val_acc: 0.9696
# 10000/10000 [==============================] - 0s
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1459 - acc: 0.9615 - val_loss: 0.1048 - val_acc: 0.9693
#  9312/10000 [==========================>...] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 2.2902 - acc: 0.1315 - val_loss: 2.2618 - val_acc: 0.1849
#  9760/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.2040 - acc: 0.9416 - val_loss: 0.1524 - val_acc: 0.9580
#  9632/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////4//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1389 - acc: 0.9642 - val_loss: 0.1017 - val_acc: 0.9739
#  9344/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1053 - acc: 0.9705 - val_loss: 0.0854 - val_acc: 0.9750
#  9632/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1319 - acc: 0.9621 - val_loss: 0.1714 - val_acc: 0.9455
#  9248/10000 [==========================>...] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1321 - acc: 0.9655 - val_loss: 0.0974 - val_acc: 0.9726
#  9696/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s - loss: 1.9860 - acc: 0.2731 - val_loss: 1.4613 - val_acc: 0.4765
#  9856/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1893 - acc: 0.9463 - val_loss: 0.1333 - val_acc: 0.9595
#  9600/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////5//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1266 - acc: 0.9673 - val_loss: 0.0948 - val_acc: 0.9752
#  9760/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0985 - acc: 0.9722 - val_loss: 0.0789 - val_acc: 0.9773
#  9632/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1206 - acc: 0.9654 - val_loss: 0.0871 - val_acc: 0.9726
#  9280/10000 [==========================>...] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1163 - acc: 0.9691 - val_loss: 0.0892 - val_acc: 0.9747
# 10000/10000 [==============================] - 0s
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 1.4089 - acc: 0.4699 - val_loss: 1.1539 - val_acc: 0.5750
#  9632/10000 [===========================>..] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1721 - acc: 0.9504 - val_loss: 0.1198 - val_acc: 0.9649
#  9376/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////6//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1140 - acc: 0.9705 - val_loss: 0.0887 - val_acc: 0.9760
#  9920/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0893 - acc: 0.9751 - val_loss: 0.0741 - val_acc: 0.9787
#  9760/10000 [============================>.] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1087 - acc: 0.9687 - val_loss: 0.0778 - val_acc: 0.9758
#  9472/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1094 - acc: 0.9706 - val_loss: 0.0832 - val_acc: 0.9778
#  9696/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 1.2249 - acc: 0.5452 - val_loss: 1.0292 - val_acc: 0.6340
#  9888/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1653 - acc: 0.9519 - val_loss: 0.1278 - val_acc: 0.9635
#  9984/10000 [============================>.] - ETA: 0s///////////////////////////////////////////////
# /////////////////////7//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1089 - acc: 0.9714 - val_loss: 0.0883 - val_acc: 0.9765
#  9952/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0846 - acc: 0.9759 - val_loss: 0.0779 - val_acc: 0.9797
#  9888/10000 [============================>.] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1006 - acc: 0.9708 - val_loss: 0.0787 - val_acc: 0.9758
#  9792/10000 [============================>.] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0979 - acc: 0.9740 - val_loss: 0.0845 - val_acc: 0.9763
#  9632/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 1.1097 - acc: 0.6001 - val_loss: 0.9226 - val_acc: 0.6814
#  9856/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1529 - acc: 0.9560 - val_loss: 0.1122 - val_acc: 0.9692
#  9984/10000 [============================>.] - ETA: 0s///////////////////////////////////////////////
# /////////////////////8//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0973 - acc: 0.9742 - val_loss: 0.0832 - val_acc: 0.9788
#  9440/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0775 - acc: 0.9777 - val_loss: 0.0806 - val_acc: 0.9787
#  9728/10000 [============================>.] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0938 - acc: 0.9725 - val_loss: 0.0796 - val_acc: 0.9753
#  9696/10000 [============================>.] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0917 - acc: 0.9751 - val_loss: 0.0817 - val_acc: 0.9777
#  9536/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 1.0119 - acc: 0.6456 - val_loss: 0.8230 - val_acc: 0.7363
#  9696/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1455 - acc: 0.9580 - val_loss: 0.1110 - val_acc: 0.9671
#  9248/10000 [==========================>...] - ETA: 0s///////////////////////////////////////////////
# /////////////////////9//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0975 - acc: 0.9750 - val_loss: 0.0813 - val_acc: 0.9782
#  9440/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0755 - acc: 0.9791 - val_loss: 0.0761 - val_acc: 0.9807
#  9568/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0862 - acc: 0.9746 - val_loss: 0.0720 - val_acc: 0.9774
#  9824/10000 [============================>.] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0870 - acc: 0.9767 - val_loss: 0.0814 - val_acc: 0.9786
#  9664/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.9257 - acc: 0.6867 - val_loss: 0.7437 - val_acc: 0.7706
#  9600/10000 [===========================>..] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1399 - acc: 0.9600 - val_loss: 0.1059 - val_acc: 0.9703
#  9696/10000 [============================>.] - ETA: 0s///////////////////////////////////////////////
# /////////////////////10//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0910 - acc: 0.9763 - val_loss: 0.0925 - val_acc: 0.9776
#  9504/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0667 - acc: 0.9804 - val_loss: 0.0777 - val_acc: 0.9794
#  9472/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0821 - acc: 0.9761 - val_loss: 0.0673 - val_acc: 0.9789
#  9600/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0830 - acc: 0.9774 - val_loss: 0.0799 - val_acc: 0.9787
#  9536/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s - loss: 0.8517 - acc: 0.7201 - val_loss: 0.6743 - val_acc: 0.7986
#  9856/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s - loss: 0.1320 - acc: 0.9616 - val_loss: 0.0994 - val_acc: 0.9728
#  9312/10000 [==========================>...] - ETA: 0s///////////////////////////////////////////////
# /////////////////////11//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0866 - acc: 0.9773 - val_loss: 0.0815 - val_acc: 0.9794
#  9632/10000 [===========================>..] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0626 - acc: 0.9823 - val_loss: 0.0749 - val_acc: 0.9801
#  9600/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0769 - acc: 0.9770 - val_loss: 0.0722 - val_acc: 0.9768
#  9632/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0771 - acc: 0.9791 - val_loss: 0.0815 - val_acc: 0.9770
#  9504/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.7882 - acc: 0.7493 - val_loss: 0.6098 - val_acc: 0.8307
#  9696/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1243 - acc: 0.9644 - val_loss: 0.0988 - val_acc: 0.9723
#  9632/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////12//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0788 - acc: 0.9788 - val_loss: 0.0888 - val_acc: 0.9778
#  9984/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0593 - acc: 0.9825 - val_loss: 0.0704 - val_acc: 0.9823
#  9696/10000 [============================>.] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0724 - acc: 0.9784 - val_loss: 0.0664 - val_acc: 0.9803
#  9952/10000 [============================>.] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0710 - acc: 0.9813 - val_loss: 0.0874 - val_acc: 0.9780
#  9920/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.7221 - acc: 0.7814 - val_loss: 0.5353 - val_acc: 0.8621
#  9760/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1227 - acc: 0.9649 - val_loss: 0.0955 - val_acc: 0.9725
#  9312/10000 [==========================>...] - ETA: 0s///////////////////////////////////////////////
# /////////////////////13//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0771 - acc: 0.9793 - val_loss: 0.0801 - val_acc: 0.9790
#  9248/10000 [==========================>...] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0566 - acc: 0.9838 - val_loss: 0.0678 - val_acc: 0.9815
#  9632/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0686 - acc: 0.9794 - val_loss: 0.0675 - val_acc: 0.9795
#  9376/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0685 - acc: 0.9818 - val_loss: 0.0830 - val_acc: 0.9781
#  9696/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.6510 - acc: 0.8106 - val_loss: 0.4669 - val_acc: 0.8809
#  9472/10000 [===========================>..] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1183 - acc: 0.9665 - val_loss: 0.0954 - val_acc: 0.9733
#  9952/10000 [============================>.] - ETA: 0s///////////////////////////////////////////////
# /////////////////////14//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0747 - acc: 0.9803 - val_loss: 0.0858 - val_acc: 0.9788
#  9184/10000 [==========================>...] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0547 - acc: 0.9842 - val_loss: 0.0781 - val_acc: 0.9788
#  9568/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0622 - acc: 0.9812 - val_loss: 0.0672 - val_acc: 0.9806
#  9600/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0700 - acc: 0.9814 - val_loss: 0.0893 - val_acc: 0.9764
#  9440/10000 [===========================>..] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s - loss: 0.5913 - acc: 0.8340 - val_loss: 0.4145 - val_acc: 0.8915
#  9824/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1139 - acc: 0.9680 - val_loss: 0.0917 - val_acc: 0.9745
#  9248/10000 [==========================>...] - ETA: 0s///////////////////////////////////////////////
# /////////////////////15//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0713 - acc: 0.9810 - val_loss: 0.0898 - val_acc: 0.9781
#  9952/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0527 - acc: 0.9849 - val_loss: 0.0708 - val_acc: 0.9820
#  9376/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0614 - acc: 0.9818 - val_loss: 0.0701 - val_acc: 0.9799
#  9600/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0651 - acc: 0.9824 - val_loss: 0.0820 - val_acc: 0.9795
# 10000/10000 [==============================] - 0s
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.5432 - acc: 0.8482 - val_loss: 0.3828 - val_acc: 0.9002
#  9952/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s - loss: 0.1127 - acc: 0.9674 - val_loss: 0.0941 - val_acc: 0.9737
#  9344/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////16//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0666 - acc: 0.9820 - val_loss: 0.0833 - val_acc: 0.9784
#  9984/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0491 - acc: 0.9859 - val_loss: 0.0711 - val_acc: 0.9813
#  9600/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0569 - acc: 0.9831 - val_loss: 0.0719 - val_acc: 0.9797
#  9952/10000 [============================>.] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0605 - acc: 0.9835 - val_loss: 0.0807 - val_acc: 0.9807
#  9728/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s - loss: 0.5104 - acc: 0.8583 - val_loss: 0.3593 - val_acc: 0.9047
#  9344/10000 [===========================>..] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1045 - acc: 0.9701 - val_loss: 0.0888 - val_acc: 0.9756
#  9632/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////17//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0656 - acc: 0.9824 - val_loss: 0.0859 - val_acc: 0.9796
#  9696/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0481 - acc: 0.9864 - val_loss: 0.0729 - val_acc: 0.9812
#  9472/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0547 - acc: 0.9833 - val_loss: 0.0687 - val_acc: 0.9813
#  9472/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0621 - acc: 0.9834 - val_loss: 0.0846 - val_acc: 0.9784
# 10000/10000 [==============================] - 0s
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.4773 - acc: 0.8682 - val_loss: 0.3432 - val_acc: 0.9082
#  9728/10000 [============================>.] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1023 - acc: 0.9702 - val_loss: 0.0891 - val_acc: 0.9763
#  9440/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////18//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0612 - acc: 0.9836 - val_loss: 0.0861 - val_acc: 0.9787
#  9696/10000 [============================>.] - ETA: 0sTraining model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0458 - acc: 0.9869 - val_loss: 0.0703 - val_acc: 0.9823
#  9568/10000 [===========================>..] - ETA: 0sTraining model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0514 - acc: 0.9838 - val_loss: 0.0706 - val_acc: 0.9807
#  9440/10000 [===========================>..] - ETA: 0sTraining model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.0571 - acc: 0.9847 - val_loss: 0.0771 - val_acc: 0.9809
#  9920/10000 [============================>.] - ETA: 0sTraining model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.4559 - acc: 0.8751 - val_loss: 0.3244 - val_acc: 0.9128
#  9280/10000 [==========================>...] - ETA: 0sTraining model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s - loss: 0.1012 - acc: 0.9709 - val_loss: 0.0858 - val_acc: 0.9771
#  9632/10000 [===========================>..] - ETA: 0s///////////////////////////////////////////////
# /////////////////////19//////////////////////////
# ///////////////////////////////////////////////

# %%
plot_results(acc)
# Out:
# <img src="data:image/png;base64,..." width="997">
