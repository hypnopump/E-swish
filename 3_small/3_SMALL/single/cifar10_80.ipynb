# %%
""" First attempt to build a ConvNet in Keras
	for CV (Computer Vision), more specifically for 
	Image Recognition (classification problem).
"""

# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import keras.backend as K 
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.optimizers import Optimizer
from keras.callbacks import EarlyStopping
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.callbacks import EarlyStopping

# For reproducibility
np.random.seed(42)
# Out:
# Using TensorFlow backend.

# %%
"""Retrieve the CIFAR dataset and process the data."""

classes = ["airplane", "automobile ", "bird ", "cat" , "deer", "dog", "frog" , "horse", "ship", "truck"]
nb_classes = 10
batch_size = 64
input_dim = 32*32*3
nb_train = 50000
nb_test = 10000
# Get the data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Preprocess it
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
# convert class vectors to binary class matrices
y_train = np_utils.to_categorical(y_train, nb_classes)
y_test = np_utils.to_categorical(y_test, nb_classes)

print("Cifar 10 data retrieved and processed")
# Out:
# Cifar 10 data retrieved and processed

# %%
# Swish activation function
# x*sigmoid(x)
def swish(x):
    return x*K.sigmoid(x)

# Custom activation function 1
# mix between relu and positive part of swish mirrored across x=1
def e_swish_1(x):
    return K.maximum(0.0, x*(2-K.sigmoid(x)))

# Custom activation function 2
# positive part of swish mirrored across x=1
def e_swish_2(x):
    return K.maximum(x*K.sigmoid(x), x*(2-K.sigmoid(x)))

def leaky(x, alpha=0.3):
    return K.maximum(x*0.3, x)

# %%
activations = [e_swish_2, swish, "relu", "elu", leaky] # e_swish_1, 
names = activations[:]
for i,a in enumerate(names):
    if not isinstance(a, str):
        names[i] = a.__name__
print(names)
# Out:
# ['e_swish_2', 'swish', 'relu', 'elu', 'leaky']

# %%
def create_models():
    models = []

    # create models - ALCAIDES, SWISH, RELU, DIGMOID, TANH
    for act in activations:
        model = Sequential()
        # First Convolutional Block
        model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation=act, input_shape=x_train.shape[1:]))
        model.add(MaxPooling2D(pool_size = 2))
        model.add(Dropout(0.15))
        model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation=act))
        model.add(MaxPooling2D(pool_size = 2))
        model.add(Dropout(0.15))
        # Second Convolutional Block
        model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation=act))
        model.add(Dropout(0.15))
        model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation=act))
        model.add(MaxPooling2D(pool_size = 2))
        model.add(Dropout(0.15))
        # Last Convolutional Block
        model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation=act))
        model.add(MaxPooling2D(pool_size = 2))
        model.add(Dropout(0.15))
        # Flatten and pass trough fully connected layers
        model.add(Flatten())
        # Classification task
        model.add(Dense(64, activation=act))
        model.add(Dense(10, activation='softmax'))
        models.append(model)

    # Compile models
    for model in models:
        model.compile(loss='categorical_crossentropy', optimizer='adamax', metrics=['accuracy'])
    
    # Create Accuracy history
    acc = []
    for model in models: acc.append([0])
        
    return models, acc

# %%
def test_against(models, epochs, acc):
    for j in range(epochs):
        for i,model in enumerate(models):
            print("Training model {0}".format(i))
            model.fit(x_train, y_train, epochs=1, batch_size=128,  verbose=1, shuffle=True, validation_split=0.1)
            scores = model.evaluate(x_test, y_test)
            acc[i].append(scores[1]*100)
        print("\n")
        print("///////////////////////////////////////////////")
        print("/////////////////////{0}//////////////////////////".format(j+1))
        print("///////////////////////////////////////////////")

    return models, acc

# Plot the evolution of the accuracies
def plot_results(accs):
	plt.figure()
	for acc in accs:
		plt.plot(100-np.array(acc))
	plt.grid()
	plt.legend(names, loc='upper right')
	plt.show()

# %%
kernels, acc = create_models()
print(len(kernels))
# Out:
# 5

# %%
# visualize model structure
kernels[0].summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 311,242
# Trainable params: 311,242
# Non-trainable params: 0
# _________________________________________________________________

# %%
kernels, acc = test_against(kernels, 15, acc)
# Out:
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 69s 2ms/step - loss: 1.6976 - acc: 0.3744 - val_loss: 1.3962 - val_acc: 0.4834
# 10000/10000 [==============================] - 5s 472us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 1.8148 - acc: 0.3319 - val_loss: 1.5505 - val_acc: 0.4276
# 10000/10000 [==============================] - 4s 391us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 1.8444 - acc: 0.3122 - val_loss: 1.5623 - val_acc: 0.4188
# 10000/10000 [==============================] - 4s 359us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 51s 1ms/step - loss: 1.5581 - acc: 0.4349 - val_loss: 1.2773 - val_acc: 0.5470
# 10000/10000 [==============================] - 4s 373us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 56s 1ms/step - loss: 1.7194 - acc: 0.3631 - val_loss: 1.4221 - val_acc: 0.4790
# 10000/10000 [==============================] - 4s 394us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////1//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 65s 1ms/step - loss: 1.2700 - acc: 0.5414 - val_loss: 1.1194 - val_acc: 0.6022
# 10000/10000 [==============================] - 4s 448us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 1.4695 - acc: 0.4649 - val_loss: 1.2991 - val_acc: 0.5282
# 10000/10000 [==============================] - 4s 382us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 1.4578 - acc: 0.4654 - val_loss: 1.2983 - val_acc: 0.5232
# 10000/10000 [==============================] - 4s 353us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 1.1725 - acc: 0.5823 - val_loss: 1.0648 - val_acc: 0.6224
# 10000/10000 [==============================] - 4s 369us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 1.3366 - acc: 0.5168 - val_loss: 1.2218 - val_acc: 0.5552
# 10000/10000 [==============================] - 4s 401us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////2//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 1.0857 - acc: 0.6138 - val_loss: 0.9996 - val_acc: 0.6414
# 10000/10000 [==============================] - 5s 459us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 1.2954 - acc: 0.5310 - val_loss: 1.1789 - val_acc: 0.5806
# 10000/10000 [==============================] - 4s 387us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 1.2885 - acc: 0.5318 - val_loss: 1.1458 - val_acc: 0.5898
# 10000/10000 [==============================] - 4s 361us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 1.0096 - acc: 0.6435 - val_loss: 0.9350 - val_acc: 0.6766
# 10000/10000 [==============================] - 4s 379us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 1.1551 - acc: 0.5873 - val_loss: 1.0234 - val_acc: 0.6384
# 10000/10000 [==============================] - 4s 389us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////3//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.9590 - acc: 0.6589 - val_loss: 0.8549 - val_acc: 0.6966
# 10000/10000 [==============================] - 5s 461us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 1.1719 - acc: 0.5804 - val_loss: 1.0834 - val_acc: 0.6132
# 10000/10000 [==============================] - 4s 391us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 1.1633 - acc: 0.5810 - val_loss: 1.0906 - val_acc: 0.6100
# 10000/10000 [==============================] - 4s 365us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.9116 - acc: 0.6786 - val_loss: 0.9011 - val_acc: 0.6912
# 10000/10000 [==============================] - 4s 377us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 1.0390 - acc: 0.6325 - val_loss: 0.9202 - val_acc: 0.6774
# 10000/10000 [==============================] - 4s 390us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////4//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 65s 1ms/step - loss: 0.8648 - acc: 0.6933 - val_loss: 0.8512 - val_acc: 0.7024
# 10000/10000 [==============================] - 5s 459us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 1.0690 - acc: 0.6192 - val_loss: 0.9937 - val_acc: 0.6436
# 10000/10000 [==============================] - 4s 384us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 1.0697 - acc: 0.6189 - val_loss: 0.9723 - val_acc: 0.6568
# 10000/10000 [==============================] - 4s 363us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.8432 - acc: 0.7041 - val_loss: 0.8331 - val_acc: 0.7136
# 10000/10000 [==============================] - 4s 376us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.9499 - acc: 0.6666 - val_loss: 0.9321 - val_acc: 0.6780
# 10000/10000 [==============================] - 4s 382us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////5//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 65s 1ms/step - loss: 0.7983 - acc: 0.7189 - val_loss: 0.7610 - val_acc: 0.7362
# 10000/10000 [==============================] - 4s 448us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.9950 - acc: 0.6468 - val_loss: 0.9927 - val_acc: 0.6464
# 10000/10000 [==============================] - 4s 386us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.9911 - acc: 0.6461 - val_loss: 0.8923 - val_acc: 0.6934
# 10000/10000 [==============================] - 4s 358us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.7863 - acc: 0.7238 - val_loss: 0.7829 - val_acc: 0.7298
# 10000/10000 [==============================] - 4s 367us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.8798 - acc: 0.6909 - val_loss: 0.8498 - val_acc: 0.7156
# 10000/10000 [==============================] - 4s 378us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////6//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 64s 1ms/step - loss: 0.7359 - acc: 0.7389 - val_loss: 0.6933 - val_acc: 0.7632
# 10000/10000 [==============================] - 4s 449us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.9323 - acc: 0.6698 - val_loss: 0.8930 - val_acc: 0.6894
# 10000/10000 [==============================] - 4s 378us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.9251 - acc: 0.6756 - val_loss: 0.8661 - val_acc: 0.6954
# 10000/10000 [==============================] - 4s 353us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.7336 - acc: 0.7424 - val_loss: 0.7294 - val_acc: 0.7528
# 10000/10000 [==============================] - 4s 368us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.8245 - acc: 0.7116 - val_loss: 0.7889 - val_acc: 0.7288
# 10000/10000 [==============================] - 4s 378us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////7//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 64s 1ms/step - loss: 0.6875 - acc: 0.7584 - val_loss: 0.6966 - val_acc: 0.7604
# 10000/10000 [==============================] - 4s 447us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.8785 - acc: 0.6898 - val_loss: 0.8758 - val_acc: 0.6914
# 10000/10000 [==============================] - 4s 379us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.8556 - acc: 0.6974 - val_loss: 0.7975 - val_acc: 0.7236
# 10000/10000 [==============================] - 4s 355us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.6935 - acc: 0.7549 - val_loss: 0.7449 - val_acc: 0.7480
# 10000/10000 [==============================] - 4s 369us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.7731 - acc: 0.7270 - val_loss: 0.7432 - val_acc: 0.7504
# 10000/10000 [==============================] - 4s 379us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////8//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.6458 - acc: 0.7723 - val_loss: 0.7022 - val_acc: 0.7630
# 10000/10000 [==============================] - 5s 460us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.8240 - acc: 0.7096 - val_loss: 0.8250 - val_acc: 0.7132
# 10000/10000 [==============================] - 4s 393us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.8136 - acc: 0.7128 - val_loss: 0.7535 - val_acc: 0.7406
# 10000/10000 [==============================] - 4s 363us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.6515 - acc: 0.7698 - val_loss: 0.6869 - val_acc: 0.7678
# 10000/10000 [==============================] - 4s 379us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.7280 - acc: 0.7446 - val_loss: 0.7215 - val_acc: 0.7474
# 10000/10000 [==============================] - 4s 389us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////9//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 65s 1ms/step - loss: 0.6165 - acc: 0.7820 - val_loss: 0.6656 - val_acc: 0.7688
# 10000/10000 [==============================] - 5s 463us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.7696 - acc: 0.7278 - val_loss: 0.8054 - val_acc: 0.7184
# 10000/10000 [==============================] - 4s 389us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.7761 - acc: 0.7265 - val_loss: 0.7711 - val_acc: 0.7322
# 10000/10000 [==============================] - 4s 364us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.6181 - acc: 0.7809 - val_loss: 0.7081 - val_acc: 0.7560
# 10000/10000 [==============================] - 4s 382us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.6811 - acc: 0.7607 - val_loss: 0.6837 - val_acc: 0.7690
# 10000/10000 [==============================] - 4s 391us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////10//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.5698 - acc: 0.7993 - val_loss: 0.6307 - val_acc: 0.7836
# 10000/10000 [==============================] - 5s 456us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.7261 - acc: 0.7443 - val_loss: 0.7780 - val_acc: 0.7344
# 10000/10000 [==============================] - 4s 389us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.7302 - acc: 0.7424 - val_loss: 0.7124 - val_acc: 0.7486
# 10000/10000 [==============================] - 4s 366us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.5899 - acc: 0.7918 - val_loss: 0.6878 - val_acc: 0.7712
# 10000/10000 [==============================] - 4s 382us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.6540 - acc: 0.7700 - val_loss: 0.6876 - val_acc: 0.7630
# 10000/10000 [==============================] - 4s 395us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////11//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.5487 - acc: 0.8064 - val_loss: 0.6365 - val_acc: 0.7856
# 10000/10000 [==============================] - 5s 459us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.6855 - acc: 0.7586 - val_loss: 0.7651 - val_acc: 0.7380
# 10000/10000 [==============================] - 4s 391us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.6933 - acc: 0.7560 - val_loss: 0.7037 - val_acc: 0.7566
# 10000/10000 [==============================] - 4s 362us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.5629 - acc: 0.8001 - val_loss: 0.6881 - val_acc: 0.7690
# 10000/10000 [==============================] - 4s 381us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.6201 - acc: 0.7820 - val_loss: 0.6512 - val_acc: 0.7786
# 10000/10000 [==============================] - 4s 389us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////12//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 65s 1ms/step - loss: 0.5167 - acc: 0.8145 - val_loss: 0.6334 - val_acc: 0.7892
# 10000/10000 [==============================] - 4s 450us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.6446 - acc: 0.7728 - val_loss: 0.7341 - val_acc: 0.7490
# 10000/10000 [==============================] - 4s 381us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.6650 - acc: 0.7643 - val_loss: 0.6725 - val_acc: 0.7684
# 10000/10000 [==============================] - 4s 354us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.5403 - acc: 0.8086 - val_loss: 0.6725 - val_acc: 0.7752
# 10000/10000 [==============================] - 4s 372us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.5929 - acc: 0.7913 - val_loss: 0.6670 - val_acc: 0.7768
# 10000/10000 [==============================] - 4s 381us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////13//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 64s 1ms/step - loss: 0.4959 - acc: 0.8241 - val_loss: 0.6450 - val_acc: 0.7924
# 10000/10000 [==============================] - 5s 451us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.6239 - acc: 0.7794 - val_loss: 0.7548 - val_acc: 0.7452
# 10000/10000 [==============================] - 4s 380us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.6406 - acc: 0.7740 - val_loss: 0.6301 - val_acc: 0.7850
# 10000/10000 [==============================] - 4s 357us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.5083 - acc: 0.8195 - val_loss: 0.6764 - val_acc: 0.7770
# 10000/10000 [==============================] - 4s 371us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.5632 - acc: 0.8012 - val_loss: 0.6480 - val_acc: 0.7874
# 10000/10000 [==============================] - 4s 381us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////14//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 65s 1ms/step - loss: 0.4730 - acc: 0.8319 - val_loss: 0.6740 - val_acc: 0.7860
# 10000/10000 [==============================] - 5s 476us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.5881 - acc: 0.7925 - val_loss: 0.7317 - val_acc: 0.7572
# 10000/10000 [==============================] - 4s 390us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.6132 - acc: 0.7842 - val_loss: 0.6165 - val_acc: 0.7900
# 10000/10000 [==============================] - 4s 357us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.4958 - acc: 0.8238 - val_loss: 0.6749 - val_acc: 0.7802
# 10000/10000 [==============================] - 4s 374us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.5420 - acc: 0.8076 - val_loss: 0.6568 - val_acc: 0.7822
# 10000/10000 [==============================] - 4s 384us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////15//////////////////////////
# ///////////////////////////////////////////////

# %%
kernels, acc = test_against(kernels, 5, acc)
# Out:
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.4544 - acc: 0.8390 - val_loss: 0.6218 - val_acc: 0.7936
# 10000/10000 [==============================] - 5s 469us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 53s 1ms/step - loss: 0.5606 - acc: 0.8013 - val_loss: 0.7417 - val_acc: 0.7516
# 10000/10000 [==============================] - 4s 395us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.5906 - acc: 0.7925 - val_loss: 0.6206 - val_acc: 0.7808
# 10000/10000 [==============================] - 4s 359us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 51s 1ms/step - loss: 0.4730 - acc: 0.8308 - val_loss: 0.6740 - val_acc: 0.7786
# 10000/10000 [==============================] - 4s 380us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.5214 - acc: 0.8135 - val_loss: 0.6390 - val_acc: 0.7870
# 10000/10000 [==============================] - 4s 384us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////1//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.4336 - acc: 0.8459 - val_loss: 0.6607 - val_acc: 0.7920
# 10000/10000 [==============================] - 5s 453us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.5356 - acc: 0.8102 - val_loss: 0.7478 - val_acc: 0.7532
# 10000/10000 [==============================] - 4s 385us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.5663 - acc: 0.8029 - val_loss: 0.6065 - val_acc: 0.7948
# 10000/10000 [==============================] - 4s 355us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.4559 - acc: 0.8377 - val_loss: 0.6650 - val_acc: 0.7796
# 10000/10000 [==============================] - 4s 374us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.4999 - acc: 0.8238 - val_loss: 0.6236 - val_acc: 0.7958
# 10000/10000 [==============================] - 4s 392us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////2//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.4189 - acc: 0.8531 - val_loss: 0.6688 - val_acc: 0.7928
# 10000/10000 [==============================] - 5s 459us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.5150 - acc: 0.8170 - val_loss: 0.7255 - val_acc: 0.7642
# 10000/10000 [==============================] - 4s 383us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.5438 - acc: 0.8085 - val_loss: 0.5916 - val_acc: 0.7982
# 10000/10000 [==============================] - 4s 356us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 51s 1ms/step - loss: 0.4327 - acc: 0.8454 - val_loss: 0.6809 - val_acc: 0.7810
# 10000/10000 [==============================] - 4s 387us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 56s 1ms/step - loss: 0.4823 - acc: 0.8296 - val_loss: 0.6806 - val_acc: 0.7768
# 10000/10000 [==============================] - 4s 380us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////3//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 67s 1ms/step - loss: 0.3998 - acc: 0.8572 - val_loss: 0.6486 - val_acc: 0.7992
# 10000/10000 [==============================] - 4s 450us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.4888 - acc: 0.8266 - val_loss: 0.7279 - val_acc: 0.7640
# 10000/10000 [==============================] - 4s 385us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.5264 - acc: 0.8150 - val_loss: 0.5946 - val_acc: 0.7912
# 10000/10000 [==============================] - 4s 361us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 50s 1ms/step - loss: 0.4268 - acc: 0.8479 - val_loss: 0.6757 - val_acc: 0.7878
# 10000/10000 [==============================] - 4s 375us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.4696 - acc: 0.8341 - val_loss: 0.6522 - val_acc: 0.7898
# 10000/10000 [==============================] - 4s 378us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////4//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 66s 1ms/step - loss: 0.3893 - acc: 0.8602 - val_loss: 0.6497 - val_acc: 0.8012
# 10000/10000 [==============================] - 5s 453us/step
# Training model 1
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 54s 1ms/step - loss: 0.4675 - acc: 0.8334 - val_loss: 0.6975 - val_acc: 0.7688
# 10000/10000 [==============================] - 4s 391us/step
# Training model 2
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 49s 1ms/step - loss: 0.5129 - acc: 0.8192 - val_loss: 0.5919 - val_acc: 0.7976
# 10000/10000 [==============================] - 4s 359us/step
# Training model 3
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 51s 1ms/step - loss: 0.4079 - acc: 0.8533 - val_loss: 0.6929 - val_acc: 0.7854
# 10000/10000 [==============================] - 4s 401us/step
# Training model 4
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/1
# 45000/45000 [==============================] - 55s 1ms/step - loss: 0.4501 - acc: 0.8399 - val_loss: 0.6488 - val_acc: 0.7922
# 10000/10000 [==============================] - 4s 381us/step
#
#
# ///////////////////////////////////////////////
# /////////////////////5//////////////////////////
# ///////////////////////////////////////////////

# %%
# New (paper writing)
# %matplotlib notebook
plot_results(acc)
print(acc)
# Out:
# <img src="data:image/png;base64,..." width="957">
# [[0, 49.16, 59.309999999999995, 62.5, 67.83, 69.49, 72.13000000000001, 74.78, 74.13, 75.16000000000001, 76.21, 77.02, 77.48, 78.16, 77.66999999999999, 76.97, 78.34, 78.11, 77.72, 78.60000000000001, 78.55], [0, 42.809999999999995, 51.43, 56.85, 60.22, 64.16, 64.42999999999999, 67.82000000000001, 68.35, 69.89999999999999, 71.37, 72.13000000000001, 72.61, 73.61, 73.22, 74.13, 74.46000000000001, 74.5, 74.88, 75.53999999999999, 76.27000000000001], [0, 42.86, 52.129999999999995, 58.550000000000004, 59.8, 64.23, 67.51, 67.58999999999999, 70.63000000000001, 72.16, 71.7, 73.65, 74.15, 75.61, 76.71, 77.28, 76.67, 77.88000000000001, 78.46, 78.12, 78.18], [0, 53.339999999999996, 61.839999999999996, 67.11, 68.54, 70.5, 72.42, 73.67, 74.02, 75.48, 74.36, 75.78, 75.72, 76.79, 76.77000000000001, 77.03999999999999, 76.95, 77.47, 77.31, 77.60000000000001, 77.49000000000001], [0, 47.339999999999996, 55.05, 62.73, 66.14999999999999, 65.66, 69.07, 71.75, 73.00999999999999, 73.96000000000001, 74.79, 74.59, 76.24, 76.14, 77.06, 76.61, 77.42, 77.59, 76.32, 77.92999999999999, 78.0]]

# %%
# Original (first day)
# %matplotlib notebook
plot_results(acc)
# Out:
# <img src="data:image/png;base64,..." width="640">
