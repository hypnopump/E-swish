# %%
# Using Keras to create a 10 neurons and single layer NN
# Against the MNIST databesa

import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
import keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (7,7) # Make the figures a bit bigger
nb_classes = 10

np.random.seed(42)
# %matplotlib notebook
# Out:
# Using TensorFlow backend.

# %%
# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print("X_train original shape", X_train.shape)
print("y_train original shape", y_train.shape)

# Show some images
def show(X_train, y_train):
	for i in range(9):
	    plt.subplot(3,3,i+1)
	    plt.imshow(X_train[i], cmap='gray', interpolation='none')
	    plt.title("Class {}".format(y_train[i]))
	plt.show()

# Swish activation function
# x*sigmoid(x)
def swish(x):
    return x*K.sigmoid(x)

# Custom activation function 1
# mix between relu and positive part of swish mirrored across x=1
def e_swish_1(x):
    return K.maximum(0.0, x*(2-K.sigmoid(x)))

# Custom activation function 2
# positive part of swish mirrored across x=1
def e_swish(x):
    return K.maximum(x*K.sigmoid(x), x*(2-K.sigmoid(x)))

# Leaky ReLU
def leaky(x, alpha=0.3):
    return K.maximum(x*alpha, x)

show(X_train, y_train)

# Reshape arrays
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)

Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)
# Out:
# X_train original shape (60000, 28, 28)
# y_train original shape (60000,)
# Training matrix shape (60000, 784)
# Testing matrix shape (10000, 784)

# %%
activations = [e_swish, swish, "relu", "elu", leaky] # e_swish_1, 
names = activations[:]
for i,a in enumerate(names):
    if not isinstance(a, str):
        names[i] = a.__name__
print(names)
# Out:
# ['e_swish', 'swish', 'relu', 'elu', 'leaky']

# %%
def create_models():
    models = []

    sgd = SGD(lr=0.1)
    # create models - ALCAIDES, SWISH, RELU, DIGMOID, TANH
    for act in activations:
        model1 = Sequential()
        model1.add(Dense(200, input_dim=784, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(100, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(60, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(30, activation=act))
        model1.add(Dropout(0.2))
        model1.add(Dense(10, activation='softmax'))
        models.append(model1)

    # Compile models
    for model in models:
        with tf.device('/cpu:0'):
            model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
    
    # Create Accuracy history
    acc = []
    for model in models: acc.append([0])
        
    return models, acc

# %%
def test_against(models, epochs, acc):
   
        
    for j in range(epochs):
        for i,model in enumerate(models):
            print("Training model {0}".format(i))
            with tf.device('/cpu:0'):
                model.fit(X_train, Y_train, epochs=1, batch_size=64,  verbose=1, validation_data=(X_test, Y_test))
                scores = model.evaluate(X_test, Y_test)
            acc[i].append(scores[1]*100)
        print("///////////////////////////////////////////////")
        print("/////////////////////{0}//////////////////////////".format(j))
        print("///////////////////////////////////////////////")

    return models, acc

# Plot the evolution of the accuracies
def plot_results(accs):
    plt.figure()
    plt.title("Test error for different activation functions on MNIST")
    plt.xlabel("Number of epochs")
    plt.ylabel("Test error (%)")
    plt.xticks(range(21))
    for i,acc in enumerate(accs):
        if i>0:plt.plot(100-np.array(acc))
    plt.grid()
    plt.legend(names[0:], loc='upper right')
    plt.show()

# %%
kernels, acc = create_models()

# %%
kernels, acc = test_against(kernels, 20, acc)
# kernels_, acc = test_against(kernels_, 20, acc)
# Out:
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 7s 120us/step - loss: 0.5475 - acc: 0.8338 - val_loss: 0.1935 - val_acc: 0.9434
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 104us/step - loss: 0.4499 - acc: 0.8665 - val_loss: 0.1629 - val_acc: 0.9498
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.6578 - acc: 0.7983 - val_loss: 0.2293 - val_acc: 0.9338
# 10000/10000 [==============================] - 0s 39us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.6364 - acc: 0.7972 - val_loss: 0.1862 - val_acc: 0.9465
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.4814 - acc: 0.8525 - val_loss: 0.2242 - val_acc: 0.9274
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.5133 - acc: 0.8412 - val_loss: 0.2269 - val_acc: 0.9267
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////0//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.2563 - acc: 0.9315 - val_loss: 0.1510 - val_acc: 0.9563
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.2151 - acc: 0.9405 - val_loss: 0.1205 - val_acc: 0.9639
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.2740 - acc: 0.9210 - val_loss: 0.1586 - val_acc: 0.9517
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.2644 - acc: 0.9278 - val_loss: 0.2038 - val_acc: 0.9403
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.2879 - acc: 0.9139 - val_loss: 0.1932 - val_acc: 0.9367
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.2730 - acc: 0.9218 - val_loss: 0.1541 - val_acc: 0.9516
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////1//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.2033 - acc: 0.9470 - val_loss: 0.1228 - val_acc: 0.9657
# 10000/10000 [==============================] - 0s 40us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.1634 - acc: 0.9552 - val_loss: 0.1023 - val_acc: 0.9680
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2043 - acc: 0.9412 - val_loss: 0.1287 - val_acc: 0.9596
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2041 - acc: 0.9459 - val_loss: 0.1129 - val_acc: 0.9680
# 10000/10000 [==============================] - 0s 35us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.2331 - acc: 0.9298 - val_loss: 0.1443 - val_acc: 0.9567
# 10000/10000 [==============================] - 0s 37us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.2243 - acc: 0.9351 - val_loss: 0.1375 - val_acc: 0.9573
# 10000/10000 [==============================] - 0s 40us/step
# ///////////////////////////////////////////////
# /////////////////////2//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.1695 - acc: 0.9557 - val_loss: 0.1096 - val_acc: 0.9712
# 10000/10000 [==============================] - 0s 40us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.1406 - acc: 0.9603 - val_loss: 0.0989 - val_acc: 0.9692
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1718 - acc: 0.9504 - val_loss: 0.1216 - val_acc: 0.9629
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.1659 - acc: 0.9558 - val_loss: 0.1039 - val_acc: 0.9705
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.2050 - acc: 0.9390 - val_loss: 0.1492 - val_acc: 0.9507
# 10000/10000 [==============================] - 0s 34us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1976 - acc: 0.9424 - val_loss: 0.1263 - val_acc: 0.9588
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////3//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1532 - acc: 0.9607 - val_loss: 0.1033 - val_acc: 0.9711
# 10000/10000 [==============================] - 0s 39us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.1238 - acc: 0.9653 - val_loss: 0.0923 - val_acc: 0.9734
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1470 - acc: 0.9582 - val_loss: 0.1023 - val_acc: 0.9695
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1451 - acc: 0.9622 - val_loss: 0.0950 - val_acc: 0.9726
# 10000/10000 [==============================] - 0s 35us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1832 - acc: 0.9449 - val_loss: 0.1185 - val_acc: 0.9628
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1804 - acc: 0.9477 - val_loss: 0.1490 - val_acc: 0.9523
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////4//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1392 - acc: 0.9638 - val_loss: 0.1065 - val_acc: 0.9704
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.1071 - acc: 0.9696 - val_loss: 0.0836 - val_acc: 0.9749
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1319 - acc: 0.9621 - val_loss: 0.1713 - val_acc: 0.9455
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1316 - acc: 0.9654 - val_loss: 0.0900 - val_acc: 0.9753
# 10000/10000 [==============================] - 0s 35us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1685 - acc: 0.9491 - val_loss: 0.1141 - val_acc: 0.9656
# 10000/10000 [==============================] - 0s 35us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1696 - acc: 0.9500 - val_loss: 0.1322 - val_acc: 0.9583
# 10000/10000 [==============================] - 0s 41us/step
# ///////////////////////////////////////////////
# /////////////////////5//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.1236 - acc: 0.9680 - val_loss: 0.0936 - val_acc: 0.9747
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0998 - acc: 0.9722 - val_loss: 0.0818 - val_acc: 0.9755
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1206 - acc: 0.9654 - val_loss: 0.0871 - val_acc: 0.9726
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1155 - acc: 0.9692 - val_loss: 0.0862 - val_acc: 0.9745
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1567 - acc: 0.9527 - val_loss: 0.1017 - val_acc: 0.9675
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1555 - acc: 0.9536 - val_loss: 0.1003 - val_acc: 0.9670
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////6//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1146 - acc: 0.9701 - val_loss: 0.1045 - val_acc: 0.9720
# 10000/10000 [==============================] - 0s 39us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0900 - acc: 0.9750 - val_loss: 0.0826 - val_acc: 0.9771
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1087 - acc: 0.9687 - val_loss: 0.0777 - val_acc: 0.9757
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1103 - acc: 0.9708 - val_loss: 0.0842 - val_acc: 0.9760
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.1434 - acc: 0.9575 - val_loss: 0.0958 - val_acc: 0.9716
# 10000/10000 [==============================] - 0s 35us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1485 - acc: 0.9556 - val_loss: 0.1001 - val_acc: 0.9698
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////7//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.1073 - acc: 0.9723 - val_loss: 0.0945 - val_acc: 0.9750
# 10000/10000 [==============================] - 0s 40us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0841 - acc: 0.9760 - val_loss: 0.0784 - val_acc: 0.9792
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1006 - acc: 0.9708 - val_loss: 0.0787 - val_acc: 0.9757
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.1008 - acc: 0.9735 - val_loss: 0.0782 - val_acc: 0.9776
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1335 - acc: 0.9600 - val_loss: 0.0950 - val_acc: 0.9719
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1433 - acc: 0.9580 - val_loss: 0.1030 - val_acc: 0.9680
# 10000/10000 [==============================] - 0s 35us/step
# ///////////////////////////////////////////////
# /////////////////////8//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0996 - acc: 0.9737 - val_loss: 0.0908 - val_acc: 0.9769
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0773 - acc: 0.9774 - val_loss: 0.0759 - val_acc: 0.9794
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0938 - acc: 0.9725 - val_loss: 0.0796 - val_acc: 0.9753
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.0929 - acc: 0.9752 - val_loss: 0.0943 - val_acc: 0.9759
# 10000/10000 [==============================] - 0s 35us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.1283 - acc: 0.9613 - val_loss: 0.0899 - val_acc: 0.9730
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1372 - acc: 0.9598 - val_loss: 0.0932 - val_acc: 0.9695
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////9//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.0962 - acc: 0.9747 - val_loss: 0.0904 - val_acc: 0.9759
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0736 - acc: 0.9798 - val_loss: 0.0797 - val_acc: 0.9797
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0862 - acc: 0.9746 - val_loss: 0.0720 - val_acc: 0.9773
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0888 - acc: 0.9766 - val_loss: 0.0784 - val_acc: 0.9780
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1217 - acc: 0.9636 - val_loss: 0.0865 - val_acc: 0.9733
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1299 - acc: 0.9610 - val_loss: 0.0918 - val_acc: 0.9710
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////10//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0896 - acc: 0.9767 - val_loss: 0.0979 - val_acc: 0.9741
# 10000/10000 [==============================] - 0s 39us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0667 - acc: 0.9807 - val_loss: 0.0850 - val_acc: 0.9753
# 10000/10000 [==============================] - 0s 39us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0821 - acc: 0.9762 - val_loss: 0.0673 - val_acc: 0.9789
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0821 - acc: 0.9781 - val_loss: 0.0974 - val_acc: 0.9751
# 10000/10000 [==============================] - 0s 35us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.1137 - acc: 0.9658 - val_loss: 0.0846 - val_acc: 0.9742
# 10000/10000 [==============================] - 0s 38us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.1260 - acc: 0.9623 - val_loss: 0.0981 - val_acc: 0.9706
# 10000/10000 [==============================] - 0s 39us/step
# ///////////////////////////////////////////////
# /////////////////////11//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0882 - acc: 0.9765 - val_loss: 0.0914 - val_acc: 0.9771
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0616 - acc: 0.9825 - val_loss: 0.0811 - val_acc: 0.9797
# 10000/10000 [==============================] - 0s 39us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0769 - acc: 0.9771 - val_loss: 0.0722 - val_acc: 0.9768
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0784 - acc: 0.9787 - val_loss: 0.0739 - val_acc: 0.9793
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1112 - acc: 0.9665 - val_loss: 0.0815 - val_acc: 0.9741
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1221 - acc: 0.9636 - val_loss: 0.0938 - val_acc: 0.9707
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////12//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0781 - acc: 0.9789 - val_loss: 0.0976 - val_acc: 0.9773
# 10000/10000 [==============================] - 0s 40us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0609 - acc: 0.9824 - val_loss: 0.0706 - val_acc: 0.9819
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0724 - acc: 0.9784 - val_loss: 0.0664 - val_acc: 0.9804
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0715 - acc: 0.9808 - val_loss: 0.0740 - val_acc: 0.9805
# 10000/10000 [==============================] - 0s 34us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 88us/step - loss: 0.1072 - acc: 0.9679 - val_loss: 0.0802 - val_acc: 0.9771
# 10000/10000 [==============================] - 0s 34us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.1190 - acc: 0.9642 - val_loss: 0.0930 - val_acc: 0.9724
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////13//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0775 - acc: 0.9793 - val_loss: 0.0776 - val_acc: 0.9810
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0577 - acc: 0.9836 - val_loss: 0.0701 - val_acc: 0.9819
# 10000/10000 [==============================] - 0s 39us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0686 - acc: 0.9794 - val_loss: 0.0676 - val_acc: 0.9795
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0716 - acc: 0.9808 - val_loss: 0.0778 - val_acc: 0.9800
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1019 - acc: 0.9686 - val_loss: 0.0777 - val_acc: 0.9760
# 10000/10000 [==============================] - 0s 37us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1104 - acc: 0.9664 - val_loss: 0.0951 - val_acc: 0.9713
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////14//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0745 - acc: 0.9799 - val_loss: 0.0880 - val_acc: 0.9789
# 10000/10000 [==============================] - 0s 39us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.0544 - acc: 0.9843 - val_loss: 0.0713 - val_acc: 0.9812
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0622 - acc: 0.9812 - val_loss: 0.0672 - val_acc: 0.9806
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0698 - acc: 0.9815 - val_loss: 0.0752 - val_acc: 0.9815
# 10000/10000 [==============================] - 0s 34us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.1028 - acc: 0.9691 - val_loss: 0.0804 - val_acc: 0.9747
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.1123 - acc: 0.9663 - val_loss: 0.0796 - val_acc: 0.9753
# 10000/10000 [==============================] - 0s 37us/step
# ///////////////////////////////////////////////
# /////////////////////15//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0710 - acc: 0.9816 - val_loss: 0.0798 - val_acc: 0.9797
# 10000/10000 [==============================] - 0s 37us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0515 - acc: 0.9851 - val_loss: 0.0705 - val_acc: 0.9814
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0614 - acc: 0.9818 - val_loss: 0.0701 - val_acc: 0.9799
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0668 - acc: 0.9830 - val_loss: 0.0840 - val_acc: 0.9783
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0971 - acc: 0.9708 - val_loss: 0.0738 - val_acc: 0.9783
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1077 - acc: 0.9668 - val_loss: 0.0863 - val_acc: 0.9734
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////16//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 96us/step - loss: 0.0688 - acc: 0.9818 - val_loss: 0.0821 - val_acc: 0.9799
# 10000/10000 [==============================] - 0s 40us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0489 - acc: 0.9860 - val_loss: 0.0768 - val_acc: 0.9814
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 94us/step - loss: 0.0569 - acc: 0.9831 - val_loss: 0.0719 - val_acc: 0.9798
# 10000/10000 [==============================] - 0s 38us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0599 - acc: 0.9836 - val_loss: 0.0802 - val_acc: 0.9806
# 10000/10000 [==============================] - 0s 34us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.0932 - acc: 0.9716 - val_loss: 0.0808 - val_acc: 0.9761
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1036 - acc: 0.9688 - val_loss: 0.0824 - val_acc: 0.9740
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////17//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0675 - acc: 0.9824 - val_loss: 0.0721 - val_acc: 0.9822
# 10000/10000 [==============================] - 0s 41us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0451 - acc: 0.9867 - val_loss: 0.0728 - val_acc: 0.9826
# 10000/10000 [==============================] - 0s 39us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0547 - acc: 0.9833 - val_loss: 0.0687 - val_acc: 0.9812
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0613 - acc: 0.9832 - val_loss: 0.0779 - val_acc: 0.9801
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 93us/step - loss: 0.0931 - acc: 0.9726 - val_loss: 0.0726 - val_acc: 0.9780
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.1012 - acc: 0.9685 - val_loss: 0.0768 - val_acc: 0.9759
# 10000/10000 [==============================] - 0s 38us/step
# ///////////////////////////////////////////////
# /////////////////////18//////////////////////////
# ///////////////////////////////////////////////
# Training model 0
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.0647 - acc: 0.9825 - val_loss: 0.0787 - val_acc: 0.9796
# 10000/10000 [==============================] - 0s 38us/step
# Training model 1
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.0461 - acc: 0.9869 - val_loss: 0.0705 - val_acc: 0.9823
# 10000/10000 [==============================] - 0s 40us/step
# Training model 2
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0514 - acc: 0.9838 - val_loss: 0.0706 - val_acc: 0.9805
# 10000/10000 [==============================] - 0s 37us/step
# Training model 3
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0573 - acc: 0.9848 - val_loss: 0.0766 - val_acc: 0.9806
# 10000/10000 [==============================] - 0s 36us/step
# Training model 4
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0902 - acc: 0.9732 - val_loss: 0.0726 - val_acc: 0.9778
# 10000/10000 [==============================] - 0s 36us/step
# Training model 5
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 95us/step - loss: 0.0985 - acc: 0.9702 - val_loss: 0.0885 - val_acc: 0.9735
# 10000/10000 [==============================] - 0s 39us/step
# ///////////////////////////////////////////////
# /////////////////////19//////////////////////////
# ///////////////////////////////////////////////

# %%
plot_results(acc)
print(acc)
# Out:
# <img src="data:image/png;base64,..." width="966">
# [[0, 94.340000000000003, 95.63000000000001, 96.569999999999993, 97.11999999999999, 97.109999999999999, 97.040000000000006, 97.469999999999999, 97.200000000000003, 97.5, 97.689999999999998, 97.590000000000003, 97.409999999999997, 97.709999999999994, 97.72999999999999, 98.099999999999994, 97.890000000000001, 97.969999999999999, 97.989999999999995, 98.219999999999999, 97.960000000000008], [0, 94.980000000000004, 96.390000000000001, 96.799999999999997, 96.920000000000002, 97.340000000000003, 97.489999999999995, 97.549999999999997, 97.709999999999994, 97.920000000000002, 97.939999999999998, 97.969999999999999, 97.530000000000001, 97.969999999999999, 98.189999999999998, 98.189999999999998, 98.11999999999999, 98.140000000000001, 98.140000000000001, 98.260000000000005, 98.22999999999999], [0, 93.379999999999995, 95.170000000000002, 95.960000000000008, 96.289999999999992, 96.950000000000003, 94.549999999999997, 97.260000000000005, 97.570000000000007, 97.570000000000007, 97.530000000000001, 97.72999999999999, 97.890000000000001, 97.680000000000007, 98.040000000000006, 97.950000000000003, 98.060000000000002, 97.989999999999995, 97.980000000000004, 98.11999999999999, 98.049999999999997], [0, 94.650000000000006, 94.030000000000001, 96.799999999999997, 97.049999999999997, 97.260000000000005, 97.530000000000001, 97.450000000000003, 97.599999999999994, 97.760000000000005, 97.590000000000003, 97.799999999999997, 97.509999999999991, 97.929999999999993, 98.049999999999997, 98.0, 98.150000000000006, 97.829999999999998, 98.060000000000002, 98.009999999999991, 98.060000000000002], [0, 92.739999999999995, 93.670000000000002, 95.670000000000002, 95.069999999999993, 96.280000000000001, 96.560000000000002, 96.75, 97.159999999999997, 97.189999999999998, 97.299999999999997, 97.330000000000013, 97.420000000000002, 97.409999999999997, 97.709999999999994, 97.599999999999994, 97.469999999999999, 97.829999999999998, 97.609999999999999, 97.799999999999997, 97.780000000000001], [0, 92.670000000000002, 95.159999999999997, 95.730000000000004, 95.879999999999995, 95.230000000000004, 95.829999999999998, 96.700000000000003, 96.980000000000004, 96.799999999999997, 96.950000000000003, 97.099999999999994, 97.060000000000002, 97.070000000000007, 97.240000000000009, 97.13000000000001, 97.530000000000001, 97.340000000000003, 97.399999999999991, 97.590000000000003, 97.350000000000009]]
