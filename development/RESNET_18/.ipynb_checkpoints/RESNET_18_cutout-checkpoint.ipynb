# %%
""" Training an slightly modified version of
    ResNet-18 to see effects of cutout+e_swish_2.
    
    Expected: > 92-93% accuracy
"""

from cutout_eraser import get_random_eraser
from resnet18_mod import ResNetPreAct

import keras
import keras.backend as K
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

#z-score
mean = np.mean(x_train,axis=(0,1,2,3))
std = np.std(x_train,axis=(0,1,2,3))
x_train = (x_train-mean)/(std+1e-7)
x_test = (x_test-mean)/(std+1e-7)

num_classes = 10
y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)
# Out:
# Using TensorFlow backend.

# %%
# Custom activation function 2
# positive part of swish mirrored across x=1
def e_swish_2(x):
    return K.maximum(x*K.sigmoid(x), x*(2-K.sigmoid(x)))

# %%
act, act_name = e_swish_2, "e_swish_2"

# %%
model = ResNetPreAct(e_swish_2, layer1_params=(3,128,2),res_layer_params=(3,32,25),reg=5e-5)
model.summary()
# Out:
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:112: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same", name="conv0", kernel_regularizer=<keras.reg..., strides=(2, 2), use_bias=False, kernel_initializer="glorot_normal")`
#   name='conv0'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv1a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv1b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv1c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:54: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   x = merge([x, input_tensor], mode='sum', name=merge_name)
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\legacy\layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv2a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv2b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv2c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv3a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv3b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv3c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv4a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv4b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv4c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv5a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv5b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv5c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv6a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv6b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv6c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv7a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv7b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv7c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv8a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv8b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv8c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv9a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv9b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv9c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv10a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv10b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv10c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv11a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv11b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv11c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv12a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv12b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv12c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv13a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv13b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv13c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv14a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv14b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv14c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv15a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv15b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv15c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv16a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv16b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv16c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv17a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv17b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv17c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv18a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv18b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv18c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv19a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv19b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv19c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv20a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv20b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv20c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv21a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv21b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv21c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv22a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv22b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv22c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv23a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv23b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv23c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv24a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv24b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv24c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (1, 1), name="conv25a", kernel_initializer="glorot_normal", use_bias=False, kernel_regularizer=<keras.reg...)`
#   name=conv_name+'a'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same", name="conv25b", kernel_regularizer=<keras.reg..., use_bias=False, kernel_initializer="glorot_normal")`
#   name=conv_name+'b'
# C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), name="conv25c", kernel_regularizer=<keras.reg..., kernel_initializer="glorot_normal")`
#   name=conv_name+'c'
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cifar (InputLayer)              (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 16, 16, 128)  3456        cifar[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 16, 16, 128)  64          conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 16, 16, 128)  0           bn0[0][0]
# __________________________________________________________________________________________________
# conv1a (Conv2D)                 (None, 16, 16, 32)   4096        relu0[0][0]
# __________________________________________________________________________________________________
# bn1b (BatchNormalization)       (None, 16, 16, 32)   64          conv1a[0][0]
# __________________________________________________________________________________________________
# eswish1b (Activation)           (None, 16, 16, 32)   0           bn1b[0][0]
# __________________________________________________________________________________________________
# conv1b (Conv2D)                 (None, 16, 16, 32)   9216        eswish1b[0][0]
# __________________________________________________________________________________________________
# bn1c (BatchNormalization)       (None, 16, 16, 32)   64          conv1b[0][0]
# __________________________________________________________________________________________________
# eswish1c (Activation)           (None, 16, 16, 32)   0           bn1c[0][0]
# __________________________________________________________________________________________________
# conv1c (Conv2D)                 (None, 16, 16, 128)  4224        eswish1c[0][0]
# __________________________________________________________________________________________________
# merge_hey1 (Merge)              (None, 16, 16, 128)  0           conv1c[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# bn2a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey1[0][0]
# __________________________________________________________________________________________________
# eswish2a (Activation)           (None, 16, 16, 128)  0           bn2a[0][0]
# __________________________________________________________________________________________________
# conv2a (Conv2D)                 (None, 16, 16, 32)   4096        eswish2a[0][0]
# __________________________________________________________________________________________________
# bn2b (BatchNormalization)       (None, 16, 16, 32)   64          conv2a[0][0]
# __________________________________________________________________________________________________
# eswish2b (Activation)           (None, 16, 16, 32)   0           bn2b[0][0]
# __________________________________________________________________________________________________
# conv2b (Conv2D)                 (None, 16, 16, 32)   9216        eswish2b[0][0]
# __________________________________________________________________________________________________
# bn2c (BatchNormalization)       (None, 16, 16, 32)   64          conv2b[0][0]
# __________________________________________________________________________________________________
# eswish2c (Activation)           (None, 16, 16, 32)   0           bn2c[0][0]
# __________________________________________________________________________________________________
# conv2c (Conv2D)                 (None, 16, 16, 128)  4224        eswish2c[0][0]
# __________________________________________________________________________________________________
# merge_hey2 (Merge)              (None, 16, 16, 128)  0           conv2c[0][0]
#                                                                  merge_hey1[0][0]
# __________________________________________________________________________________________________
# bn3a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey2[0][0]
# __________________________________________________________________________________________________
# eswish3a (Activation)           (None, 16, 16, 128)  0           bn3a[0][0]
# __________________________________________________________________________________________________
# conv3a (Conv2D)                 (None, 16, 16, 32)   4096        eswish3a[0][0]
# __________________________________________________________________________________________________
# bn3b (BatchNormalization)       (None, 16, 16, 32)   64          conv3a[0][0]
# __________________________________________________________________________________________________
# eswish3b (Activation)           (None, 16, 16, 32)   0           bn3b[0][0]
# __________________________________________________________________________________________________
# conv3b (Conv2D)                 (None, 16, 16, 32)   9216        eswish3b[0][0]
# __________________________________________________________________________________________________
# bn3c (BatchNormalization)       (None, 16, 16, 32)   64          conv3b[0][0]
# __________________________________________________________________________________________________
# eswish3c (Activation)           (None, 16, 16, 32)   0           bn3c[0][0]
# __________________________________________________________________________________________________
# conv3c (Conv2D)                 (None, 16, 16, 128)  4224        eswish3c[0][0]
# __________________________________________________________________________________________________
# merge_hey3 (Merge)              (None, 16, 16, 128)  0           conv3c[0][0]
#                                                                  merge_hey2[0][0]
# __________________________________________________________________________________________________
# bn4a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey3[0][0]
# __________________________________________________________________________________________________
# eswish4a (Activation)           (None, 16, 16, 128)  0           bn4a[0][0]
# __________________________________________________________________________________________________
# conv4a (Conv2D)                 (None, 16, 16, 32)   4096        eswish4a[0][0]
# __________________________________________________________________________________________________
# bn4b (BatchNormalization)       (None, 16, 16, 32)   64          conv4a[0][0]
# __________________________________________________________________________________________________
# eswish4b (Activation)           (None, 16, 16, 32)   0           bn4b[0][0]
# __________________________________________________________________________________________________
# conv4b (Conv2D)                 (None, 16, 16, 32)   9216        eswish4b[0][0]
# __________________________________________________________________________________________________
# bn4c (BatchNormalization)       (None, 16, 16, 32)   64          conv4b[0][0]
# __________________________________________________________________________________________________
# eswish4c (Activation)           (None, 16, 16, 32)   0           bn4c[0][0]
# __________________________________________________________________________________________________
# conv4c (Conv2D)                 (None, 16, 16, 128)  4224        eswish4c[0][0]
# __________________________________________________________________________________________________
# merge_hey4 (Merge)              (None, 16, 16, 128)  0           conv4c[0][0]
#                                                                  merge_hey3[0][0]
# __________________________________________________________________________________________________
# bn5a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey4[0][0]
# __________________________________________________________________________________________________
# eswish5a (Activation)           (None, 16, 16, 128)  0           bn5a[0][0]
# __________________________________________________________________________________________________
# conv5a (Conv2D)                 (None, 16, 16, 32)   4096        eswish5a[0][0]
# __________________________________________________________________________________________________
# bn5b (BatchNormalization)       (None, 16, 16, 32)   64          conv5a[0][0]
# __________________________________________________________________________________________________
# eswish5b (Activation)           (None, 16, 16, 32)   0           bn5b[0][0]
# __________________________________________________________________________________________________
# conv5b (Conv2D)                 (None, 16, 16, 32)   9216        eswish5b[0][0]
# __________________________________________________________________________________________________
# bn5c (BatchNormalization)       (None, 16, 16, 32)   64          conv5b[0][0]
# __________________________________________________________________________________________________
# eswish5c (Activation)           (None, 16, 16, 32)   0           bn5c[0][0]
# __________________________________________________________________________________________________
# conv5c (Conv2D)                 (None, 16, 16, 128)  4224        eswish5c[0][0]
# __________________________________________________________________________________________________
# merge_hey5 (Merge)              (None, 16, 16, 128)  0           conv5c[0][0]
#                                                                  merge_hey4[0][0]
# __________________________________________________________________________________________________
# bn6a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey5[0][0]
# __________________________________________________________________________________________________
# eswish6a (Activation)           (None, 16, 16, 128)  0           bn6a[0][0]
# __________________________________________________________________________________________________
# conv6a (Conv2D)                 (None, 16, 16, 32)   4096        eswish6a[0][0]
# __________________________________________________________________________________________________
# bn6b (BatchNormalization)       (None, 16, 16, 32)   64          conv6a[0][0]
# __________________________________________________________________________________________________
# eswish6b (Activation)           (None, 16, 16, 32)   0           bn6b[0][0]
# __________________________________________________________________________________________________
# conv6b (Conv2D)                 (None, 16, 16, 32)   9216        eswish6b[0][0]
# __________________________________________________________________________________________________
# bn6c (BatchNormalization)       (None, 16, 16, 32)   64          conv6b[0][0]
# __________________________________________________________________________________________________
# eswish6c (Activation)           (None, 16, 16, 32)   0           bn6c[0][0]
# __________________________________________________________________________________________________
# conv6c (Conv2D)                 (None, 16, 16, 128)  4224        eswish6c[0][0]
# __________________________________________________________________________________________________
# merge_hey6 (Merge)              (None, 16, 16, 128)  0           conv6c[0][0]
#                                                                  merge_hey5[0][0]
# __________________________________________________________________________________________________
# bn7a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey6[0][0]
# __________________________________________________________________________________________________
# eswish7a (Activation)           (None, 16, 16, 128)  0           bn7a[0][0]
# __________________________________________________________________________________________________
# conv7a (Conv2D)                 (None, 16, 16, 32)   4096        eswish7a[0][0]
# __________________________________________________________________________________________________
# bn7b (BatchNormalization)       (None, 16, 16, 32)   64          conv7a[0][0]
# __________________________________________________________________________________________________
# eswish7b (Activation)           (None, 16, 16, 32)   0           bn7b[0][0]
# __________________________________________________________________________________________________
# conv7b (Conv2D)                 (None, 16, 16, 32)   9216        eswish7b[0][0]
# __________________________________________________________________________________________________
# bn7c (BatchNormalization)       (None, 16, 16, 32)   64          conv7b[0][0]
# __________________________________________________________________________________________________
# eswish7c (Activation)           (None, 16, 16, 32)   0           bn7c[0][0]
# __________________________________________________________________________________________________
# conv7c (Conv2D)                 (None, 16, 16, 128)  4224        eswish7c[0][0]
# __________________________________________________________________________________________________
# merge_hey7 (Merge)              (None, 16, 16, 128)  0           conv7c[0][0]
#                                                                  merge_hey6[0][0]
# __________________________________________________________________________________________________
# bn8a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey7[0][0]
# __________________________________________________________________________________________________
# eswish8a (Activation)           (None, 16, 16, 128)  0           bn8a[0][0]
# __________________________________________________________________________________________________
# conv8a (Conv2D)                 (None, 16, 16, 32)   4096        eswish8a[0][0]
# __________________________________________________________________________________________________
# bn8b (BatchNormalization)       (None, 16, 16, 32)   64          conv8a[0][0]
# __________________________________________________________________________________________________
# eswish8b (Activation)           (None, 16, 16, 32)   0           bn8b[0][0]
# __________________________________________________________________________________________________
# conv8b (Conv2D)                 (None, 16, 16, 32)   9216        eswish8b[0][0]
# __________________________________________________________________________________________________
# bn8c (BatchNormalization)       (None, 16, 16, 32)   64          conv8b[0][0]
# __________________________________________________________________________________________________
# eswish8c (Activation)           (None, 16, 16, 32)   0           bn8c[0][0]
# __________________________________________________________________________________________________
# conv8c (Conv2D)                 (None, 16, 16, 128)  4224        eswish8c[0][0]
# __________________________________________________________________________________________________
# merge_hey8 (Merge)              (None, 16, 16, 128)  0           conv8c[0][0]
#                                                                  merge_hey7[0][0]
# __________________________________________________________________________________________________
# bn9a (BatchNormalization)       (None, 16, 16, 128)  64          merge_hey8[0][0]
# __________________________________________________________________________________________________
# eswish9a (Activation)           (None, 16, 16, 128)  0           bn9a[0][0]
# __________________________________________________________________________________________________
# conv9a (Conv2D)                 (None, 16, 16, 32)   4096        eswish9a[0][0]
# __________________________________________________________________________________________________
# bn9b (BatchNormalization)       (None, 16, 16, 32)   64          conv9a[0][0]
# __________________________________________________________________________________________________
# eswish9b (Activation)           (None, 16, 16, 32)   0           bn9b[0][0]
# __________________________________________________________________________________________________
# conv9b (Conv2D)                 (None, 16, 16, 32)   9216        eswish9b[0][0]
# __________________________________________________________________________________________________
# bn9c (BatchNormalization)       (None, 16, 16, 32)   64          conv9b[0][0]
# __________________________________________________________________________________________________
# eswish9c (Activation)           (None, 16, 16, 32)   0           bn9c[0][0]
# __________________________________________________________________________________________________
# conv9c (Conv2D)                 (None, 16, 16, 128)  4224        eswish9c[0][0]
# __________________________________________________________________________________________________
# merge_hey9 (Merge)              (None, 16, 16, 128)  0           conv9c[0][0]
#                                                                  merge_hey8[0][0]
# __________________________________________________________________________________________________
# bn10a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey9[0][0]
# __________________________________________________________________________________________________
# eswish10a (Activation)          (None, 16, 16, 128)  0           bn10a[0][0]
# __________________________________________________________________________________________________
# conv10a (Conv2D)                (None, 16, 16, 32)   4096        eswish10a[0][0]
# __________________________________________________________________________________________________
# bn10b (BatchNormalization)      (None, 16, 16, 32)   64          conv10a[0][0]
# __________________________________________________________________________________________________
# eswish10b (Activation)          (None, 16, 16, 32)   0           bn10b[0][0]
# __________________________________________________________________________________________________
# conv10b (Conv2D)                (None, 16, 16, 32)   9216        eswish10b[0][0]
# __________________________________________________________________________________________________
# bn10c (BatchNormalization)      (None, 16, 16, 32)   64          conv10b[0][0]
# __________________________________________________________________________________________________
# eswish10c (Activation)          (None, 16, 16, 32)   0           bn10c[0][0]
# __________________________________________________________________________________________________
# conv10c (Conv2D)                (None, 16, 16, 128)  4224        eswish10c[0][0]
# __________________________________________________________________________________________________
# merge_hey10 (Merge)             (None, 16, 16, 128)  0           conv10c[0][0]
#                                                                  merge_hey9[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  merge_hey17[0][0]
# __________________________________________________________________________________________________
# bn19a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey18[0][0]
# __________________________________________________________________________________________________
# eswish19a (Activation)          (None, 16, 16, 128)  0           bn19a[0][0]
# __________________________________________________________________________________________________
# conv19a (Conv2D)                (None, 16, 16, 32)   4096        eswish19a[0][0]
# __________________________________________________________________________________________________
# bn19b (BatchNormalization)      (None, 16, 16, 32)   64          conv19a[0][0]
# __________________________________________________________________________________________________
# eswish19b (Activation)          (None, 16, 16, 32)   0           bn19b[0][0]
# __________________________________________________________________________________________________
# conv19b (Conv2D)                (None, 16, 16, 32)   9216        eswish19b[0][0]
# __________________________________________________________________________________________________
# bn19c (BatchNormalization)      (None, 16, 16, 32)   64          conv19b[0][0]
# __________________________________________________________________________________________________
# eswish19c (Activation)          (None, 16, 16, 32)   0           bn19c[0][0]
# __________________________________________________________________________________________________
# conv19c (Conv2D)                (None, 16, 16, 128)  4224        eswish19c[0][0]
# __________________________________________________________________________________________________
# merge_hey19 (Merge)             (None, 16, 16, 128)  0           conv19c[0][0]
#                                                                  merge_hey18[0][0]
# __________________________________________________________________________________________________
# bn20a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey19[0][0]
# __________________________________________________________________________________________________
# eswish20a (Activation)          (None, 16, 16, 128)  0           bn20a[0][0]
# __________________________________________________________________________________________________
# conv20a (Conv2D)                (None, 16, 16, 32)   4096        eswish20a[0][0]
# __________________________________________________________________________________________________
# bn20b (BatchNormalization)      (None, 16, 16, 32)   64          conv20a[0][0]
# __________________________________________________________________________________________________
# eswish20b (Activation)          (None, 16, 16, 32)   0           bn20b[0][0]
# __________________________________________________________________________________________________
# conv20b (Conv2D)                (None, 16, 16, 32)   9216        eswish20b[0][0]
# __________________________________________________________________________________________________
# bn20c (BatchNormalization)      (None, 16, 16, 32)   64          conv20b[0][0]
# __________________________________________________________________________________________________
# eswish20c (Activation)          (None, 16, 16, 32)   0           bn20c[0][0]
# __________________________________________________________________________________________________
# conv20c (Conv2D)                (None, 16, 16, 128)  4224        eswish20c[0][0]
# __________________________________________________________________________________________________
# merge_hey20 (Merge)             (None, 16, 16, 128)  0           conv20c[0][0]
#                                                                  merge_hey19[0][0]
# __________________________________________________________________________________________________
# bn21a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey20[0][0]
# __________________________________________________________________________________________________
# eswish21a (Activation)          (None, 16, 16, 128)  0           bn21a[0][0]
# __________________________________________________________________________________________________
# conv21a (Conv2D)                (None, 16, 16, 32)   4096        eswish21a[0][0]
# __________________________________________________________________________________________________
# bn21b (BatchNormalization)      (None, 16, 16, 32)   64          conv21a[0][0]
# __________________________________________________________________________________________________
# eswish21b (Activation)          (None, 16, 16, 32)   0           bn21b[0][0]
# __________________________________________________________________________________________________
# conv21b (Conv2D)                (None, 16, 16, 32)   9216        eswish21b[0][0]
# __________________________________________________________________________________________________
# bn21c (BatchNormalization)      (None, 16, 16, 32)   64          conv21b[0][0]
# __________________________________________________________________________________________________
# eswish21c (Activation)          (None, 16, 16, 32)   0           bn21c[0][0]
# __________________________________________________________________________________________________
# conv21c (Conv2D)                (None, 16, 16, 128)  4224        eswish21c[0][0]
# __________________________________________________________________________________________________
# merge_hey21 (Merge)             (None, 16, 16, 128)  0           conv21c[0][0]
#                                                                  merge_hey20[0][0]
# __________________________________________________________________________________________________
# bn22a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey21[0][0]
# __________________________________________________________________________________________________
# eswish22a (Activation)          (None, 16, 16, 128)  0           bn22a[0][0]
# __________________________________________________________________________________________________
# conv22a (Conv2D)                (None, 16, 16, 32)   4096        eswish22a[0][0]
# __________________________________________________________________________________________________
# bn22b (BatchNormalization)      (None, 16, 16, 32)   64          conv22a[0][0]
# __________________________________________________________________________________________________
# eswish22b (Activation)          (None, 16, 16, 32)   0           bn22b[0][0]
# __________________________________________________________________________________________________
# conv22b (Conv2D)                (None, 16, 16, 32)   9216        eswish22b[0][0]
# __________________________________________________________________________________________________
# bn22c (BatchNormalization)      (None, 16, 16, 32)   64          conv22b[0][0]
# __________________________________________________________________________________________________
# eswish22c (Activation)          (None, 16, 16, 32)   0           bn22c[0][0]
# __________________________________________________________________________________________________
# conv22c (Conv2D)                (None, 16, 16, 128)  4224        eswish22c[0][0]
# __________________________________________________________________________________________________
# merge_hey22 (Merge)             (None, 16, 16, 128)  0           conv22c[0][0]
#                                                                  merge_hey21[0][0]
# __________________________________________________________________________________________________
# bn23a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey22[0][0]
# __________________________________________________________________________________________________
# eswish23a (Activation)          (None, 16, 16, 128)  0           bn23a[0][0]
# __________________________________________________________________________________________________
# conv23a (Conv2D)                (None, 16, 16, 32)   4096        eswish23a[0][0]
# __________________________________________________________________________________________________
# bn23b (BatchNormalization)      (None, 16, 16, 32)   64          conv23a[0][0]
# __________________________________________________________________________________________________
# eswish23b (Activation)          (None, 16, 16, 32)   0           bn23b[0][0]
# __________________________________________________________________________________________________
# conv23b (Conv2D)                (None, 16, 16, 32)   9216        eswish23b[0][0]
# __________________________________________________________________________________________________
# bn23c (BatchNormalization)      (None, 16, 16, 32)   64          conv23b[0][0]
# __________________________________________________________________________________________________
# eswish23c (Activation)          (None, 16, 16, 32)   0           bn23c[0][0]
# __________________________________________________________________________________________________
# conv23c (Conv2D)                (None, 16, 16, 128)  4224        eswish23c[0][0]
# __________________________________________________________________________________________________
# merge_hey23 (Merge)             (None, 16, 16, 128)  0           conv23c[0][0]
#                                                                  merge_hey22[0][0]
# __________________________________________________________________________________________________
# bn24a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey23[0][0]
# __________________________________________________________________________________________________
# eswish24a (Activation)          (None, 16, 16, 128)  0           bn24a[0][0]
# __________________________________________________________________________________________________
# conv24a (Conv2D)                (None, 16, 16, 32)   4096        eswish24a[0][0]
# __________________________________________________________________________________________________
# bn24b (BatchNormalization)      (None, 16, 16, 32)   64          conv24a[0][0]
# __________________________________________________________________________________________________
# eswish24b (Activation)          (None, 16, 16, 32)   0           bn24b[0][0]
# __________________________________________________________________________________________________
# conv24b (Conv2D)                (None, 16, 16, 32)   9216        eswish24b[0][0]
# __________________________________________________________________________________________________
# bn24c (BatchNormalization)      (None, 16, 16, 32)   64          conv24b[0][0]
# __________________________________________________________________________________________________
# eswish24c (Activation)          (None, 16, 16, 32)   0           bn24c[0][0]
# __________________________________________________________________________________________________
# conv24c (Conv2D)                (None, 16, 16, 128)  4224        eswish24c[0][0]
# __________________________________________________________________________________________________
# merge_hey24 (Merge)             (None, 16, 16, 128)  0           conv24c[0][0]
#                                                                  merge_hey23[0][0]
# __________________________________________________________________________________________________
# bn25a (BatchNormalization)      (None, 16, 16, 128)  64          merge_hey24[0][0]
# __________________________________________________________________________________________________
# eswish25a (Activation)          (None, 16, 16, 128)  0           bn25a[0][0]
# __________________________________________________________________________________________________
# conv25a (Conv2D)                (None, 16, 16, 32)   4096        eswish25a[0][0]
# __________________________________________________________________________________________________
# bn25b (BatchNormalization)      (None, 16, 16, 32)   64          conv25a[0][0]
# __________________________________________________________________________________________________
# eswish25b (Activation)          (None, 16, 16, 32)   0           bn25b[0][0]
# __________________________________________________________________________________________________
# conv25b (Conv2D)                (None, 16, 16, 32)   9216        eswish25b[0][0]
# __________________________________________________________________________________________________
# bn25c (BatchNormalization)      (None, 16, 16, 32)   64          conv25b[0][0]
# __________________________________________________________________________________________________
# eswish25c (Activation)          (None, 16, 16, 32)   0           bn25c[0][0]
# __________________________________________________________________________________________________
# conv25c (Conv2D)                (None, 16, 16, 128)  4224        eswish25c[0][0]
# __________________________________________________________________________________________________
# merge_hey25 (Merge)             (None, 16, 16, 128)  0           conv25c[0][0]
#                                                                  merge_hey24[0][0]
# __________________________________________________________________________________________________
# bnF (BatchNormalization)        (None, 16, 16, 128)  64          merge_hey25[0][0]
# __________________________________________________________________________________________________
# reluF (Activation)              (None, 16, 16, 128)  0           bnF[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 128)    0           reluF[0][0]
# __________________________________________________________________________________________________
# flat (Flatten)                  (None, 128)          0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 10)           1290        flat[0][0]
# ==================================================================================================
# Total params: 448,010
# Trainable params: 445,578
# Non-trainable params: 2,432
# __________________________________________________________________________________________________

# %%
# Data augmentation come at me
""" With 50% probability, erase 16*16 pixel squares. 
    - p=0.5 for 50% probability
    - s_l, s_h = 0.5 for only 16*16 (out of 32*32) pixels cut.
    - r_1, r_2 = 1 for squares, not rectangles
    - v_l, v_h = 0,255 since data is not normalized. Can change to 0,1 if it is.
"""
eraser = get_random_eraser(p=0.5, s_l=0.375, s_h = 0.375, r_1=1, r_2=1, v_l=0, v_h=255)

datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=10,
    fill_mode = "constant",
    width_shift_range=0.125,
    height_shift_range=0.125,
    horizontal_flip=True,
    vertical_flip=False,
    preprocessing_function=eraser
    )
datagen.fit(x_train)

# %%
def schedule(x):
    if x<50:
        return 1e-3
    elif x<75:
        return 1e-4 
    else:
        return 1e-5

# %%
#training
batch_size  = 44
epochs = 50

opt = keras.optimizers.Adam()
lr_1 = keras.callbacks.LearningRateScheduler(schedule)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
print("Finished compiling")

####################
# Network training #
####################
                     
print("Gonna fit the model")
his = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,
                          epochs=epochs,verbose=1,validation_data=(x_test, y_test), callbacks=[lr_1])
print(his.history)
# Out:
# Finished compiling
# Gonna fit the model
# Epoch 1/100
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# ResourceExhaustedError: OOM when allocating tensor with shape[50,16,16,32]
# 	 [[Node: eswish25c/mul = Mul[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"](bn25c/cond/Merge, eswish25c/Sigmoid)]]
# 	 [[Node: training/Adam/gradients/AddN/_3059 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_14601_training/Adam/gradients/AddN", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-7-d1a44f1e585f> in <module>()
#      14 print("Gonna fit the model")
#      15 his = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,
# ---> 16                           epochs=epochs,verbose=1,validation_data=(x_test, y_test), callbacks=[lr_1])
#      17 print(his.history)
#      18 print(model.evaluate(x_test, y_test))
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      85                 warnings.warn('Update your `' + object_name +
#      86                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 87             return func(*args, **kwargs)
#      88         wrapper._original_function = func
#      89         return wrapper
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2145                     outs = self.train_on_batch(x, y,
#    2146                                                sample_weight=sample_weight,
# -> 2147                                                class_weight=class_weight)
#    2148
#    2149                     if not isinstance(outs, list):
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1837             ins = x + y + sample_weights
#    1838         self._make_train_function()
# -> 1839         outputs = self.train_function(ins)
#    1840         if len(outputs) == 1:
#    1841             return outputs[0]
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[50,16,16,32]
# 	 [[Node: eswish25c/mul = Mul[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"](bn25c/cond/Merge, eswish25c/Sigmoid)]]
# 	 [[Node: training/Adam/gradients/AddN/_3059 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_14601_training/Adam/gradients/AddN", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
#
# Caused by op 'eswish25c/mul', defined at:
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tornado\ioloop.py", line 887, in start
#     handler_func(fd_obj, events)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tornado\stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py", line 2717, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py", line 2821, in run_ast_nodes
#     if self.run_code(code, result):
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-9e3e8f4fd8ce>", line 1, in <module>
#     model = ResNetPreAct(e_swish_2, layer1_params=(3,128,2),res_layer_params=(3,32,25),reg=5e-5)
#   File "C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py", line 125, in ResNetPreAct
#     use_shortcuts=use_shortcuts
#   File "C:\Users\Eric\Desktop\Programming\PYTHON\AI\TENSORFLOW\KERAS\learning_keras\ALCAIDE ACTIVATION\development\RESNET_18\resnet18_mod.py", line 46, in rnpa_bottleneck_layer
#     x = Activation(act, name=relu_name+'c')(x)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\engine\topology.py", line 603, in __call__
#     output = self.call(inputs, **kwargs)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\keras\layers\core.py", line 294, in call
#     return self.activation(inputs)
#   File "<ipython-input-2-d1f0053539cb>", line 4, in e_swish_2
#     return K.maximum(x*K.sigmoid(x), x*(2-K.sigmoid(x)))
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\math_ops.py", line 900, in binary_op_wrapper
#     return func(x, y, name=name)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\math_ops.py", line 1123, in _mul_dispatch
#     return gen_math_ops._mul(x, y, name=name)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\ops\gen_math_ops.py", line 2785, in _mul
#     "Mul", x=x, y=y, name=name)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\ops.py", line 3042, in create_op
#     op_def=op_def)
#   File "c:\users\eric\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\framework\ops.py", line 1521, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[50,16,16,32]
# 	 [[Node: eswish25c/mul = Mul[T=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"](bn25c/cond/Merge, eswish25c/Sigmoid)]]
# 	 [[Node: training/Adam/gradients/AddN/_3059 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_14601_training/Adam/gradients/AddN", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]

# %%
#training
batch_size  = 44
epochs = 100

opt = keras.optimizers.Adam()
lr_1 = keras.callbacks.LearningRateScheduler(schedule)
model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
print("Finished compiling")

####################
# Network training #
####################
                     
print("Gonna fit the model")
his = model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),steps_per_epoch=x_train.shape[0] // batch_size,
                          epochs=epochs,verbose=1,validation_data=(x_test, y_test), callbacks=[lr_1], initial_epoch=50)
print(his.history)

# %%
print(model.evaluate(x_test, y_test))
model.save('resnet_18_eswish_cutout.h5')
