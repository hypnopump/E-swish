# %%
import json
import numpy as np 
import matplotlib.pyplot as plt

# %%
filenames = ["log.txt", "log (1).txt", "log (2).txt"]
plots = []

for log in filenames:
    results = []
    # Extract raw logs
    with open(log) as f:
        content = f.readlines()
    #Clean them up
    for i, line in enumerate(content):
        s = line[12:]
        json_acceptable_string = s.replace("'", "\"")
        d = json.loads(json_acceptable_string)
        results.append(d["test_acc"])
        
    plots.append(results)
    print("\n", results)
# Out:
#  [59.53999999999999, 65.7, 68.41, 75.18, 76.63, 76.51, 77.23, 81.22, 76.89, 82.36, 81.3, 79.57, 80.2, 83.39999999999999, 82.50999999999999, 79.46, 75.17, 82.26, 83.94, 85.33999999999999, 83.78, 80.74, 83.38, 81.07, 83.02000000000001, 84.87, 85.25, 85.88, 84.03, 85.23, 85.36, 84.39, 84.43, 83.91999999999999, 85.1, 83.49, 81.55, 84.67, 84.57000000000001, 83.87, 84.36, 86.07000000000001, 82.72, 84.69, 84.09, 85.67, 83.58, 84.17, 84.67, 83.7, 85.13, 84.11, 83.77, 85.24000000000001, 83.96000000000001, 82.2, 86.46000000000001, 87.02, 83.97, 91.96, 91.95, 92.28, 92.24, 91.78, 91.94, 91.75999999999999, 91.72, 91.21000000000001, 91.69, 91.16, 90.78, 91.03999999999999, 91.19, 91.09, 90.60000000000001, 91.57, 91.27, 89.87, 91.0, 90.75999999999999, 90.53999999999999, 91.19, 90.27000000000001, 91.03999999999999, 91.4, 90.68, 90.81, 91.16, 90.77, 90.82000000000001, 91.17999999999999, 90.25999999999999, 89.75999999999999, 90.95, 91.25999999999999, 90.32, 91.33, 91.31, 91.03999999999999, 90.07000000
# ...

# %%
print(max(plots[0]), max(plots[1]), max(plots[2]))
# Out:
# 94.21000000000001 94.41000000000001 92.30000000000001

# %%
# %matplotlib notebook
plt.figure()
for result in plots:
    plt.plot(100-np.array(result))

plt.ylim(0, 45)
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="975">
